# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ufc.csv")

# %%
data
# Out:
#         Fighter  Time(sec)
# 0     Dillashaw        935
# 1     Dillashaw       1340
# 2     Dillashaw       1346
# 3        Rousey         16
# 4        Rousey         14
# 5        Rousey         34
# 6   Jedrzejczyk        862
# 7   Jedrzejczyk        557
# 8   Jedrzejczyk        900
# 9       Johnson       1500
# 10      Johnson       1499
# 11      Johnson       1049
# 12         Aldo       1500
# 13         Aldo       1500
# 14         Aldo       1020
# 15    Dos Anjos       1500
# 16    Dos Anjos        900
# 17    Dos Anjos        152
# 18       Lawler       1260
# 19       Lawler       1500
# 20       Lawler       1500
# 21      Weidman        173
# 22      Weidman       1500
# 23      Weidman        376
# 24       Werdum        733
# 25       Werdum        447
# 26       Werdum       1500

# %%
byfighter = data.groupby(by="Fighter")

# %%
byfighter.ngroups
# Out:
# 9

# %%
byfighter.mean()
# Out:
#                Time(sec)
# Fighter
# Aldo         1340.000000
# Dillashaw    1207.000000
# Dos Anjos     850.666667
# Jedrzejczyk   773.000000
# Johnson      1349.333333
# Lawler       1420.000000
# Rousey         21.333333
# Weidman       683.000000
# Werdum        893.333333

# %%
avg_time = byfighter.mean();

# %%
print(avg_time);
# Out:
#                Time(sec)
# Fighter
# Aldo         1340.000000
# Dillashaw    1207.000000
# Dos Anjos     850.666667
# Jedrzejczyk   773.000000
# Johnson      1349.333333
# Lawler       1420.000000
# Rousey         21.333333
# Weidman       683.000000
# Werdum        893.333333

# %%
byfighter.describe()
# Out:
#                      Time(sec)
# Fighter
# Aldo        count     3.000000
#             mean   1340.000000
#             std     277.128129
#             min    1020.000000
#             25%    1260.000000
#             50%    1500.000000
#             75%    1500.000000
#             max    1500.000000
# Dillashaw   count     3.000000
#             mean   1207.000000
#             std     235.578013
#             min     935.000000
#             25%    1137.500000
#             50%    1340.000000
#             75%    1343.000000
#             max    1346.000000
# Dos Anjos   count     3.000000
#             mean    850.666667
#             std     675.352747
#             min     152.000000
#             25%     526.000000
#             50%     900.000000
#             75%    1200.000000
#             max    1500.000000
# Jedrzejczyk count     3.000000
#             mean    773.000000
#             std     188.023935
#             min     557.000000
#             25%     709.500000
# ...

# %%
std = byfighter.std();

# %%
print(std);
# Out:
#               Time(sec)
# Fighter
# Aldo         277.128129
# Dillashaw    235.578013
# Dos Anjos    675.352747
# Jedrzejczyk  188.023935
# Johnson      260.096777
# Lawler       138.564065
# Rousey        11.015141
# Weidman      714.785982
# Werdum       544.501913

# %%
p = avg_time.plot(figsize=(15,5),legend=False,kind="bar",rot=45,color="blue",fontsize=16,yerr=std);
p.set_title("Average time to finish of 2015 UFC champions that won their last 3 professional fights", fontsize=18);
p.set_xlabel("UFC Fighter", fontsize=18);
p.set_ylabel("Time (seconds)", fontsize=18);
p.set_ylim(0,1800);
